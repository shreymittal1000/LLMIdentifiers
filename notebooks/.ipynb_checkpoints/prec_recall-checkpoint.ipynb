# %%
from collections import defaultdict
import json
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
from sklearn.metrics import precision_score, recall_score, confusion_matrix

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.display import display, HTML
display(HTML("<style>.output_wrapper, .output {overflow: visible !important;}</style>"))
# Out:
# <style>.output_wrapper, .output {overflow: visible !important;}</style>

# %%
def load_data(path):
    data = []
    for root, dirs, files in os.walk(path):
        for filename in files:
            if filename.endswith(".json"):
                file_path = os.path.join(root, filename)
                try:
                    with open(file_path, "r") as f:
                        entry = json.load(f)
                        data.append(entry)
                except json.JSONDecodeError as e:
                    print(f"Skipped invalid JSON: {file_path} ({e})")
                    
    print(f"Loaded {len(data)} valid JSON result files from '{folder_path}' and its subfolders.")
    return data

folder_path = "../results/base/base_cues_5/"
data_cues_5 = load_data(folder_path)
folder_path = "../results/base/base_cues_10/"
data_cues_10 = load_data(folder_path)
folder_path = "../results/base/base_none_5/"
data_none_5 = load_data(folder_path)
folder_path = "../results/base/base_none_10/"
data_none_10 = load_data(folder_path)

data_cues = data_cues_5 + data_cues_10
data_none = data_none_5 + data_none_10
data_5 = data_cues_5 + data_none_5
data_10 = data_cues_10 + data_none_10
# Out:
# Loaded 3772 valid JSON result files from '../results/base_cues_5/' and its subfolders.
# Loaded 6697 valid JSON result files from '../results/base_cues_10/' and its subfolders.
# Loaded 4218 valid JSON result files from '../results/base_none_5/' and its subfolders.
# Loaded 4151 valid JSON result files from '../results/base_none_10/' and its subfolders.

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd

labels = sorted(["gpt", "llama", "gemini", "claude", "qwen", "deepseek", "mistral"])
pretty_names = {
    "gpt": "GPT",
    "llama": "LLaMA",
    "mistral": "Mistral",
    "claude": "Claude",
    "qwen": "Qwen",
    "gemini": "Gemini",
    "deepseek": "DeepSeek"
}

def extract_useful_information(data):
    y_true, y_pred, y_guesser = [], [], []
    for entry in data:
        y_true.append(entry['model_general_name_1'])  # agent_0 guess target
        y_pred.append(entry['agent_0_guess'])
        y_guesser.append(entry['model_general_name_0'])
        y_true.append(entry['model_general_name_0'])  # agent_1 guess target
        y_pred.append(entry['agent_1_guess'])
        y_guesser.append(entry['model_general_name_1'])
    
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_guesser = np.array(y_guesser)
    y_true_pred = y_true == y_pred
    guesses_df = pd.DataFrame({"y_guesser": y_guesser, "y_guessee": y_true, "y_pred": y_pred, "y_pred_is_true": y_true_pred})
    return guesses_df

guesses_df_5c = extract_useful_information(data_cues_5)
guesses_df_10c = extract_useful_information(data_cues_10)
guesses_df_5n = extract_useful_information(data_none_5)
guesses_df_10n = extract_useful_information(data_none_10)

guesses_df_cues = extract_useful_information(data_cues)
guesses_df_none = extract_useful_information(data_none)
guesses_df_5 = extract_useful_information(data_5)
guesses_df_10 = extract_useful_information(data_10)

# %%
def calculate(guesses_df):
    all_positives = guesses_df.groupby(["y_guesser", "y_pred"]).agg(all_positives=("y_pred", "size"))
    all_positives.index.set_names(['y_guesser', 'y_guessee'], inplace=True) 
    agg = guesses_df.groupby(["y_guesser", "y_guessee"]).agg(true_positives=("y_pred_is_true", "sum"), tp_and_fn=("y_guessee", "size"))
    agg["all_positives"] = all_positives["all_positives"]
    agg["precision"] = agg["true_positives"] / agg["all_positives"]
    agg["recall"] = agg["true_positives"] / agg["tp_and_fn"]
    agg.fillna(0.0, inplace=True)
    return agg

agg_5c = calculate(guesses_df_5c)
agg_10c = calculate(guesses_df_10c)
agg_5n = calculate(guesses_df_5n)
agg_10n = calculate(guesses_df_10n)

agg_c = calculate(guesses_df_cues)
agg_n = calculate(guesses_df_none)
agg_5 = calculate(guesses_df_5)
agg_10 = calculate(guesses_df_10)

# %%
matplotlib.rcParams.update({"font.family": "serif"})

def plot_heatmap(df, save_file_name, title):
    matrix = df.unstack(level=1)
    plt.figure(figsize=(14, 12))
    ax = sns.heatmap(
        matrix,
        annot=True, fmt='.2f',
        cmap='YlGnBu',
        linewidths=0.3,
        cbar_kws={"shrink": 0.7},
        annot_kws={"fontsize": 24}
    )
    ax.set_title(title, fontsize=30)
    
    xticks = ax.get_xticklabels()
    yticks = ax.get_yticklabels()
    x_labels = [pretty_names.get(label.get_text(), label.get_text()) for label in xticks]
    y_labels = [pretty_names.get(label.get_text(), label.get_text()) for label in yticks]
    ax.set_xticklabels(x_labels, rotation=45, ha='right', fontsize=28)
    ax.set_yticklabels(y_labels, rotation=0, fontsize=28)
    
    ax.set_xlabel('Guessed Model', fontsize=28)
    ax.set_ylabel('Guesser Model', fontsize=28)
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    cbar = ax.collections[0].colorbar
    cbar.ax.tick_params(labelsize=28)

    plt.tight_layout()
    plt.savefig("figures_and_files/" + save_file_name + ".eps", dpi=300, bbox_inches='tight')
    plt.show()

# %%
plot_heatmap(agg_5c["precision"], "precision_c5", 'Precision by Model: 5 Rounds With Cues')
plot_heatmap(agg_5c["recall"], "recall_c5", 'Recall by Model: 5 Rounds With Cues')
print(agg_5c["precision"].unstack().to_latex())
print("==============")
print(agg_5c["recall"].unstack().to_latex())
# Out:
# \begin{tabular}{lrrrrrrr}
# \toprule
# y_guessee & claude & deepseek & gemini & gpt & llama & mistral & qwen \\
# y_guesser &  &  &  &  &  &  &  \\
# \midrule
# claude & 0.123203 & 1.000000 & 0.000000 & 0.111111 & 0.000000 & 1.000000 & 1.000000 \\
# deepseek & 0.554455 & 0.300000 & 0.191489 & 0.173252 & 0.000000 & 1.000000 & 1.000000 \\
# gemini & 0.354651 & 0.242775 & 0.178317 & 0.096774 & 0.000000 & 1.000000 & 0.170732 \\
# gpt & 0.345622 & 0.000000 & 0.068182 & 0.167277 & 0.000000 & 0.000000 & 0.666667 \\
# llama & 0.124464 & 0.000000 & 0.089888 & 0.167082 & 0.200000 & 0.000000 & 0.500000 \\
# mistral & 0.426471 & 0.104294 & 0.262295 & 0.175601 & 0.030303 & 0.000000 & 0.224719 \\
# qwen & 0.692913 & 0.100000 & 0.280193 & 0.160870 & 0.181818 & 1.000000 & 0.205433 \\
# \bottomrule
# \end{tabular}
#
# ...
# \begin{tabular}{lrrrrrrr}
# \toprule
# y_guessee & claude & deepseek & gemini & gpt & llama & mistral & qwen \\
# y_guesser &  &  &  &  &  &  &  \\
# \midrule
# ...

# %%
plot_heatmap(agg_10c["precision"], "precision_c10", 'Precision by Model: 10 Rounds With Cues')
plot_heatmap(agg_10c["recall"], "recall_c10", 'Recall by Model: 10 Rounds With Cues')
print(agg_10c["precision"].unstack().to_latex())
print("==============")
print(agg_10c["recall"].unstack().to_latex())
# Out:
# \begin{tabular}{lrrrrrrr}
# \toprule
# y_guessee & claude & deepseek & gemini & gpt & llama & mistral & qwen \\
# y_guesser &  &  &  &  &  &  &  \\
# \midrule
# claude & 0.166667 & 0.928571 & 0.000000 & 0.315068 & 0.000000 & 0.000000 & 0.993289 \\
# deepseek & 0.545151 & 0.142857 & 0.166667 & 0.193076 & 0.285714 & 1.000000 & 0.333333 \\
# gemini & 0.379581 & 0.198068 & 0.146035 & 0.148230 & 1.000000 & 1.000000 & 0.350000 \\
# gpt & 0.270833 & 0.000000 & 0.045872 & 0.150265 & 0.166667 & 0.000000 & 0.750000 \\
# llama & 0.175000 & 0.000000 & 0.187500 & 0.196332 & 0.135802 & 0.000000 & 1.000000 \\
# mistral & 0.421429 & 0.192825 & 0.198198 & 0.151463 & 0.078947 & 0.117073 & 0.202247 \\
# qwen & 0.582633 & 0.000000 & 0.199052 & 0.157509 & 0.200000 & 1.000000 & 0.200573 \\
# \bottomrule
# \end{tabular}
#
# ...
# \begin{tabular}{lrrrrrrr}
# \toprule
# y_guessee & claude & deepseek & gemini & gpt & llama & mistral & qwen \\
# y_guesser &  &  &  &  &  &  &  \\
# \midrule
# ...

# %%
plot_heatmap(agg_5n["precision"], "precision_n5", 'Precision by Model: 5 Rounds No Cues')
plot_heatmap(agg_5n["recall"], "recall_n5", 'Recall by Model: 5 Rounds No Cues')
print(agg_5n["precision"].unstack().to_latex())
print("==============")
print(agg_5n["recall"].unstack().to_latex())
# Out:
# \begin{tabular}{lrrrrrrr}
# \toprule
# y_guessee & claude & deepseek & gemini & gpt & llama & mistral & qwen \\
# y_guesser &  &  &  &  &  &  &  \\
# \midrule
# claude & 0.176267 & 1.000000 & 0.000000 & 0.297297 & 0.000000 & 0.000000 & 0.934426 \\
# deepseek & 0.436937 & 0.000000 & 0.000000 & 0.166837 & 0.000000 & 0.000000 & 0.000000 \\
# gemini & 0.191781 & 0.000000 & 0.154286 & 0.340659 & 0.000000 & 0.000000 & 1.000000 \\
# gpt & 1.000000 & 0.000000 & 0.000000 & 0.149254 & 0.000000 & 0.000000 & 1.000000 \\
# llama & 1.000000 & 0.000000 & 0.000000 & 0.201550 & 0.150510 & 0.000000 & 1.000000 \\
# mistral & 0.952756 & 0.000000 & 0.176471 & 0.140665 & 0.000000 & 0.131673 & 1.000000 \\
# qwen & 0.446154 & 0.000000 & 0.785714 & 0.160606 & 0.000000 & 0.500000 & 0.078125 \\
# \bottomrule
# \end{tabular}
#
# ...
# \begin{tabular}{lrrrrrrr}
# \toprule
# y_guessee & claude & deepseek & gemini & gpt & llama & mistral & qwen \\
# y_guesser &  &  &  &  &  &  &  \\
# \midrule
# ...

# %%
plot_heatmap(agg_10n["precision"], "precision_n10", 'Precision by Model: 10 Rounds No Cues')
plot_heatmap(agg_10n["recall"], "recall_n10", 'Recall by Model: 10 Rounds No Cues')
print(agg_10n["precision"].unstack().to_latex())
print("==============")
print(agg_10n["recall"].unstack().to_latex())
# Out:
# \begin{tabular}{lrrrrrrr}
# \toprule
# y_guessee & claude & deepseek & gemini & gpt & llama & mistral & qwen \\
# y_guesser &  &  &  &  &  &  &  \\
# \midrule
# claude & 0.200000 & 1.000000 & 1.000000 & 0.248276 & 0.000000 & 0.000000 & 0.989583 \\
# deepseek & 0.495370 & 0.000000 & 0.000000 & 0.173156 & 0.000000 & 0.000000 & 0.000000 \\
# gemini & 0.251534 & 0.000000 & 0.137600 & 0.119850 & 0.000000 & 0.000000 & 1.000000 \\
# gpt & 1.000000 & 0.000000 & 0.000000 & 0.150000 & 0.000000 & 0.000000 & 0.666667 \\
# llama & 1.000000 & 0.000000 & 0.000000 & 0.165485 & 0.135705 & 0.000000 & 0.000000 \\
# mistral & 0.776119 & 0.000000 & 0.187500 & 0.145688 & 0.333333 & 0.115556 & 0.000000 \\
# qwen & 0.320856 & 0.000000 & 0.400000 & 0.180305 & 0.000000 & 0.000000 & 0.171053 \\
# \bottomrule
# \end{tabular}
#
# ...
# \begin{tabular}{lrrrrrrr}
# \toprule
# y_guessee & claude & deepseek & gemini & gpt & llama & mistral & qwen \\
# y_guesser &  &  &  &  &  &  &  \\
# \midrule
# ...

# %%
plot_heatmap(agg_c["precision"] - agg_n["precision"], "precision_cues_vs_cold", 'Precision by Model: Cues Vs Cold')
plot_heatmap(agg_c["recall"] - agg_n["recall"], "recall_cues_vs_cold", 'Recall by Model: Cues Vs Cold')

# %%
plot_heatmap(agg_10["precision"] - agg_5["precision"], "precision_10_vs_5", 'Precision by Model: 10 Vs 5 Rounds')
plot_heatmap(agg_10["recall"] - agg_5["recall"], "recall_10_vs_5", 'Recall by Model: 10 Vs 5 Rounds')
