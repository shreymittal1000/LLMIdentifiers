# %%
import json
import matplotlib.pyplot as plt
import os
import pandas as pd
from sentence_transformers import SentenceTransformer
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load data
folder_path = "results/"
data = []

for root, dirs, files in os.walk(folder_path):
    for filename in files:
        if filename.endswith(".json"):
            file_path = os.path.join(root, filename)
            try:
                with open(file_path, "r") as f:
                    entry = json.load(f)
                    data.append(entry)
            except json.JSONDecodeError as e:
                print(f"Skipped invalid JSON: {file_path} ({e})")

print(f"Loaded {len(data)} valid JSON result files from '{folder_path}' and its subfolders.")
# Out:
# Loaded 145 valid JSON result files from 'results/' and its subfolders.

# %%
justifications = []

for entry in data:
    for agent_id in [0, 1]:
        model_name = entry.get(f"model_general_name_{agent_id}", f"model_{agent_id}")
        answer = entry.get(f"agent_{agent_id}_answer", "")
        
        if isinstance(answer, str) and answer.strip():
            justifications.append({
                "agent_model": model_name,
                "text": answer.strip().lower().split("2.")[0][2:]
            })

# Create a DataFrame
df_just = pd.DataFrame(justifications)
df_just.head()

model = SentenceTransformer('sentence-t5-base')
embeddings = model.encode(df_just['text'].tolist())

# PCA dimensionality reduction
pca = PCA(n_components=2)
reduced = pca.fit_transform(embeddings)
df_just['x'] = reduced[:, 0]
df_just['y'] = reduced[:, 1]

# %%
# Set style
sns.set(style="white", font_scale=1.2)
palette = sns.color_palette("tab10", n_colors=df_just['agent_model'].nunique())

plt.figure(figsize=(8, 6))
sns.scatterplot(
    data=df_just,
    x="x",
    y="y",
    hue="agent_model",
    palette=palette,
    s=60,
    edgecolor="black",
    linewidth=0.5
)

plt.title("Justification Embeddings by Model", fontsize=14)
plt.xlabel("PC 1 (Coherence and Contextual Understanding)")
plt.ylabel("PC 2 (Nuanced and Diverse Knowledge)")
plt.legend(title="Model", loc="best", frameon=False)
sns.despine()
plt.tight_layout()
plt.savefig("4.4.png", dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/backends/backend_pgf.py:283, in LatexManager._setup_latex_process(self, expect_reply)
#     282 try:
# --> 283     self.latex = subprocess.Popen(
#     284         [mpl.rcParams["pgf.texsystem"], "-halt-on-error"],
#     285         stdin=subprocess.PIPE, stdout=subprocess.PIPE,
#     286         encoding="utf-8", cwd=self.tmpdir)
#     287 except FileNotFoundError as err:
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pdflatex'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 22
#      20 plt.legend(title="Model", loc="best", frameon=False)
#      21 sns.despine()
# ---> 22 plt.tight_layout()
#      23 plt.savefig("4.4.png", dpi=300)
#      24 plt.show()
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/pyplot.py:2833, in tight_layout(pad, h_pad, w_pad, rect)
#    2825 @_copy_docstring_and_deprecators(Figure.tight_layout)
#    2826 def tight_layout(
#    2827     *,
#    (...)   2831     rect: tuple[float, float, float, float] | None = None,
#    2832 ) -> None:
# -> 2833     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/figure.py:3640, in Figure.tight_layout(self, pad, h_pad, w_pad, rect)
#    3638 previous_engine = self.get_layout_engine()
#    3639 self.set_layout_engine(engine)
# -> 3640 engine.execute(self)
#    3641 if previous_engine is not None and not isinstance(
#    3642     previous_engine, (TightLayoutEngine, PlaceHolderLayoutEngine)
#    3643 ):
#    3644     _api.warn_external('The figure layout has changed to tight')
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/layout_engine.py:183, in TightLayoutEngine.execute(self, fig)
#     181 renderer = fig._get_renderer()
#     182 with getattr(renderer, "_draw_disabled", nullcontext)():
# --> 183     kwargs = get_tight_layout_figure(
#     184         fig, fig.axes, get_subplotspec_list(fig.axes), renderer,
#     185         pad=info['pad'], h_pad=info['h_pad'], w_pad=info['w_pad'],
#     186         rect=info['rect'])
#     187 if kwargs:
#     188     fig.subplots_adjust(**kwargs)
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/_tight_layout.py:266, in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     261         return {}
#     262     span_pairs.append((
#     263         slice(ss.rowspan.start * div_row, ss.rowspan.stop * div_row),
#     264         slice(ss.colspan.start * div_col, ss.colspan.stop * div_col)))
# --> 266 kwargs = _auto_adjust_subplotpars(fig, renderer,
#     267                                   shape=(max_nrows, max_ncols),
#     268                                   span_pairs=span_pairs,
#     269                                   subplot_list=subplot_list,
#     270                                   ax_bbox_list=ax_bbox_list,
#     271                                   pad=pad, h_pad=h_pad, w_pad=w_pad)
#     273 # kwargs can be none if tight_layout fails...
#     274 if rect is not None and kwargs is not None:
#     275     # if rect is given, the whole subplots area (including
#     276     # labels) will fit into the rect instead of the
#    (...)    280     # auto_adjust_subplotpars twice, where the second run
#     281     # with adjusted rect parameters.
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/_tight_layout.py:82, in _auto_adjust_subplotpars(fig, renderer, shape, span_pairs, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      80 for ax in subplots:
#      81     if ax.get_visible():
# ---> 82         bb += [martist._get_tightbbox_for_layout_only(ax, renderer)]
#      84 tight_bbox_raw = Bbox.union(bb)
#      85 tight_bbox = fig.transFigure.inverted().transform_bbox(tight_bbox_raw)
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/artist.py:1402, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1396 """
#    1397 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1398 *for_layout_only* kwarg; this helper tries to use the kwarg but skips it
#    1399 when encountering third-party subclasses that do not support it.
#    1400 """
#    1401 try:
# -> 1402     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1403 except TypeError:
#    1404     return obj.get_tightbbox(*args, **kwargs)
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/axes/_base.py:4548, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4546 for axis in self._axis_map.values():
#    4547     if self.axison and axis.get_visible():
# -> 4548         ba = martist._get_tightbbox_for_layout_only(axis, renderer)
#    4549         if ba:
#    4550             bb.append(ba)
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/artist.py:1402, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1396 """
#    1397 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1398 *for_layout_only* kwarg; this helper tries to use the kwarg but skips it
#    1399 when encountering third-party subclasses that do not support it.
#    1400 """
#    1401 try:
# -> 1402     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1403 except TypeError:
#    1404     return obj.get_tightbbox(*args, **kwargs)
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/axis.py:1353, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1350     renderer = self.get_figure(root=True)._get_renderer()
#    1351 ticks_to_draw = self._update_ticks()
# -> 1353 self._update_label_position(renderer)
#    1355 # go back to just this axis's tick labels
#    1356 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/axis.py:2448, in XAxis._update_label_position(self, renderer)
#    2444     return
#    2446 # get bounding boxes for this axis and any siblings
#    2447 # that have been set by `fig.align_xlabels()`
# -> 2448 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2449 x, y = self.label.get_position()
#    2451 if self.label_position == 'bottom':
#    2452     # Union with extents of the bottom spine if present, of the axes otherwise.
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/axis.py:2241, in Axis._get_tick_boxes_siblings(self, renderer)
#    2239 axis = ax._axis_map[name]
#    2240 ticks_to_draw = axis._update_ticks()
# -> 2241 tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2242 bboxes.extend(tlb)
#    2243 bboxes2.extend(tlb2)
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/axis.py:1332, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1330 if renderer is None:
#    1331     renderer = self.get_figure(root=True)._get_renderer()
# -> 1332 return ([tick.label1.get_window_extent(renderer)
#    1333          for tick in ticks if tick.label1.get_visible()],
#    1334         [tick.label2.get_window_extent(renderer)
#    1335          for tick in ticks if tick.label2.get_visible()])
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/axis.py:1332, in <listcomp>(.0)
#    1330 if renderer is None:
#    1331     renderer = self.get_figure(root=True)._get_renderer()
# -> 1332 return ([tick.label1.get_window_extent(renderer)
#    1333          for tick in ticks if tick.label1.get_visible()],
#    1334         [tick.label2.get_window_extent(renderer)
#    1335          for tick in ticks if tick.label2.get_visible()])
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/text.py:969, in Text.get_window_extent(self, renderer, dpi)
#     964     raise RuntimeError(
#     965         "Cannot get window extent of text w/o renderer. You likely "
#     966         "want to call 'figure.draw_without_rendering()' first.")
#     968 with cbook._setattr_cm(fig, dpi=dpi):
# --> 969     bbox, info, descent = self._get_layout(self._renderer)
#     970     x, y = self.get_unitless_position()
#     971     x, y = self.get_transform().transform((x, y))
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/text.py:373, in Text._get_layout(self, renderer)
#     370 ys = []
#     372 # Full vertical extent of font, including ascenders and descenders:
# --> 373 _, lp_h, lp_d = _get_text_metrics_with_cache(
#     374     renderer, "lp", self._fontproperties,
#     375     ismath="TeX" if self.get_usetex() else False,
#     376     dpi=self.get_figure(root=True).dpi)
#     377 min_dy = (lp_h - lp_d) * self._linespacing
#     379 for i, line in enumerate(lines):
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/backends/backend_pgf.py:727, in RendererPgf.get_text_width_height_descent(self, s, prop, ismath)
#     724 def get_text_width_height_descent(self, s, prop, ismath):
#     725     # docstring inherited
#     726     # get text metrics in units of latex pt, convert to display units
# --> 727     w, h, d = (LatexManager._get_cached_or_new()
#     728                .get_width_height_descent(s, prop))
#     729     # TODO: this should be latex_pt_to_in instead of mpl_pt_to_in
#     730     # but having a little bit more space around the text looks better,
#     731     # plus the bounding box reported by LaTeX is VERY narrow
#     732     f = mpl_pt_to_in * self.dpi
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/backends/backend_pgf.py:226, in LatexManager._get_cached_or_new(cls)
#     220 @classmethod
#     221 def _get_cached_or_new(cls):
#     222     """
#     223     Return the previous LatexManager if the header and tex system did not
#     224     change, or a new instance otherwise.
#     225     """
# --> 226     return cls._get_cached_or_new_impl(cls._build_latex_header())
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/backends/backend_pgf.py:231, in LatexManager._get_cached_or_new_impl(cls, header)
#     228 @classmethod
#     229 @functools.lru_cache(1)
#     230 def _get_cached_or_new_impl(cls, header):  # Helper for _get_cached_or_new.
# --> 231     return cls()
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/backends/backend_pgf.py:264, in LatexManager.__init__(self)
#     261 self._finalize_tmpdir = weakref.finalize(self, self._tmpdir.cleanup)
#     263 # test the LaTeX setup to ensure a clean startup of the subprocess
# --> 264 self._setup_latex_process(expect_reply=False)
#     265 stdout, stderr = self.latex.communicate("\n\\makeatletter\\@@end\n")
#     266 if self.latex.returncode != 0:
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/backends/backend_pgf.py:288, in LatexManager._setup_latex_process(self, expect_reply)
#     283     self.latex = subprocess.Popen(
#     284         [mpl.rcParams["pgf.texsystem"], "-halt-on-error"],
#     285         stdin=subprocess.PIPE, stdout=subprocess.PIPE,
#     286         encoding="utf-8", cwd=self.tmpdir)
#     287 except FileNotFoundError as err:
# --> 288     raise RuntimeError(
#     289         f"{mpl.rcParams['pgf.texsystem']!r} not found; install it or change "
#     290         f"rcParams['pgf.texsystem'] to an available TeX implementation"
#     291     ) from err
#     292 except OSError as err:
#     293     raise RuntimeError(
#     294         f"Error starting {mpl.rcParams['pgf.texsystem']!r}") from err
#
# RuntimeError: 'pdflatex' not found; install it or change rcParams['pgf.texsystem'] to an available TeX implementation
# Error in callback <function _draw_all_if_interactive at 0x7fc05c4f0b80> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/backends/backend_pgf.py:283, in LatexManager._setup_latex_process(self, expect_reply)
#     282 try:
# --> 283     self.latex = subprocess.Popen(
#     284         [mpl.rcParams["pgf.texsystem"], "-halt-on-error"],
#     285         stdin=subprocess.PIPE, stdout=subprocess.PIPE,
#     286         encoding="utf-8", cwd=self.tmpdir)
#     287 except FileNotFoundError as err:
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pdflatex'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/pyplot.py:279, in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/backend_bases.py:1891, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1889 if not self._is_idle_drawing:
#    1890     with self._idle_draw_cntx():
# -> 1891         self.draw(*args, **kwargs)
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/backends/backend_pgf.py:873, in FigureCanvasPgf.draw(self)
#     872 def draw(self):
# --> 873     self.figure.draw_without_rendering()
#     874     return super().draw()
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/figure.py:3273, in Figure.draw_without_rendering(self)
#    3271 renderer = _get_renderer(self)
#    3272 with renderer._draw_disabled():
# -> 3273     self.draw(renderer)
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/axes/_base.py:3174, in _AxesBase.draw(self, renderer)
#    3171     for spine in self.spines.values():
#    3172         artists.remove(spine)
# -> 3174 self._update_title_position(renderer)
#    3176 if not self.axison:
#    3177     for _axis in self._axis_map.values():
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/axes/_base.py:3106, in _AxesBase._update_title_position(self, renderer)
#    3103 bb = None
#    3104 if (ax.xaxis.get_ticks_position() in ['top', 'unknown'] or
#    3105         ax.xaxis.get_label_position() == 'top'):
# -> 3106     bb = ax.xaxis.get_tightbbox(renderer)
#    3107 if bb is None:
#    3108     # Extent of the outline for colorbars, of the axes otherwise.
#    3109     bb = ax.spines.get("outline", ax).get_window_extent()
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/axis.py:1353, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1350     renderer = self.get_figure(root=True)._get_renderer()
#    1351 ticks_to_draw = self._update_ticks()
# -> 1353 self._update_label_position(renderer)
#    1355 # go back to just this axis's tick labels
#    1356 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/axis.py:2448, in XAxis._update_label_position(self, renderer)
#    2444     return
#    2446 # get bounding boxes for this axis and any siblings
#    2447 # that have been set by `fig.align_xlabels()`
# -> 2448 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2449 x, y = self.label.get_position()
#    2451 if self.label_position == 'bottom':
#    2452     # Union with extents of the bottom spine if present, of the axes otherwise.
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/axis.py:2241, in Axis._get_tick_boxes_siblings(self, renderer)
#    2239 axis = ax._axis_map[name]
#    2240 ticks_to_draw = axis._update_ticks()
# -> 2241 tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2242 bboxes.extend(tlb)
#    2243 bboxes2.extend(tlb2)
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/axis.py:1332, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1330 if renderer is None:
#    1331     renderer = self.get_figure(root=True)._get_renderer()
# -> 1332 return ([tick.label1.get_window_extent(renderer)
#    1333          for tick in ticks if tick.label1.get_visible()],
#    1334         [tick.label2.get_window_extent(renderer)
#    1335          for tick in ticks if tick.label2.get_visible()])
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/axis.py:1332, in <listcomp>(.0)
#    1330 if renderer is None:
#    1331     renderer = self.get_figure(root=True)._get_renderer()
# -> 1332 return ([tick.label1.get_window_extent(renderer)
#    1333          for tick in ticks if tick.label1.get_visible()],
#    1334         [tick.label2.get_window_extent(renderer)
#    1335          for tick in ticks if tick.label2.get_visible()])
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/text.py:969, in Text.get_window_extent(self, renderer, dpi)
#     964     raise RuntimeError(
#     965         "Cannot get window extent of text w/o renderer. You likely "
#     966         "want to call 'figure.draw_without_rendering()' first.")
#     968 with cbook._setattr_cm(fig, dpi=dpi):
# --> 969     bbox, info, descent = self._get_layout(self._renderer)
#     970     x, y = self.get_unitless_position()
#     971     x, y = self.get_transform().transform((x, y))
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/text.py:373, in Text._get_layout(self, renderer)
#     370 ys = []
#     372 # Full vertical extent of font, including ascenders and descenders:
# --> 373 _, lp_h, lp_d = _get_text_metrics_with_cache(
#     374     renderer, "lp", self._fontproperties,
#     375     ismath="TeX" if self.get_usetex() else False,
#     376     dpi=self.get_figure(root=True).dpi)
#     377 min_dy = (lp_h - lp_d) * self._linespacing
#     379 for i, line in enumerate(lines):
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/backends/backend_pgf.py:727, in RendererPgf.get_text_width_height_descent(self, s, prop, ismath)
#     724 def get_text_width_height_descent(self, s, prop, ismath):
#     725     # docstring inherited
#     726     # get text metrics in units of latex pt, convert to display units
# --> 727     w, h, d = (LatexManager._get_cached_or_new()
#     728                .get_width_height_descent(s, prop))
#     729     # TODO: this should be latex_pt_to_in instead of mpl_pt_to_in
#     730     # but having a little bit more space around the text looks better,
#     731     # plus the bounding box reported by LaTeX is VERY narrow
#     732     f = mpl_pt_to_in * self.dpi
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/backends/backend_pgf.py:226, in LatexManager._get_cached_or_new(cls)
#     220 @classmethod
#     221 def _get_cached_or_new(cls):
#     222     """
#     223     Return the previous LatexManager if the header and tex system did not
#     224     change, or a new instance otherwise.
#     225     """
# --> 226     return cls._get_cached_or_new_impl(cls._build_latex_header())
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/backends/backend_pgf.py:231, in LatexManager._get_cached_or_new_impl(cls, header)
#     228 @classmethod
#     229 @functools.lru_cache(1)
#     230 def _get_cached_or_new_impl(cls, header):  # Helper for _get_cached_or_new.
# --> 231     return cls()
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/backends/backend_pgf.py:264, in LatexManager.__init__(self)
#     261 self._finalize_tmpdir = weakref.finalize(self, self._tmpdir.cleanup)
#     263 # test the LaTeX setup to ensure a clean startup of the subprocess
# --> 264 self._setup_latex_process(expect_reply=False)
#     265 stdout, stderr = self.latex.communicate("\n\\makeatletter\\@@end\n")
#     266 if self.latex.returncode != 0:
#
# File ~/miniconda3/envs/LLMIdentifiersEnv/lib/python3.11/site-packages/matplotlib/backends/backend_pgf.py:288, in LatexManager._setup_latex_process(self, expect_reply)
#     283     self.latex = subprocess.Popen(
#     284         [mpl.rcParams["pgf.texsystem"], "-halt-on-error"],
#     285         stdin=subprocess.PIPE, stdout=subprocess.PIPE,
#     286         encoding="utf-8", cwd=self.tmpdir)
#     287 except FileNotFoundError as err:
# --> 288     raise RuntimeError(
#     289         f"{mpl.rcParams['pgf.texsystem']!r} not found; install it or change "
#     290         f"rcParams['pgf.texsystem'] to an available TeX implementation"
#     291     ) from err
#     292 except OSError as err:
#     293     raise RuntimeError(
#     294         f"Error starting {mpl.rcParams['pgf.texsystem']!r}") from err
#
# RuntimeError: 'pdflatex' not found; install it or change rcParams['pgf.texsystem'] to an available TeX implementation

# %%
# Helper function
def show_similarities(df, embeddings, axis_label, top=True):
    direction = "max" if top else "min"
    anchor_idx = df[axis_label].idxmax() if top else df[axis_label].idxmin()
    anchor_vector = embeddings[anchor_idx].reshape(1, -1)
    similarities = cosine_similarity(anchor_vector, embeddings).flatten()

    label = f"Most {'similar' if top else 'dissimilar'} to extreme {axis_label.upper()} value ({direction}):"
    print(f"\n{label}")
    sorted_indices = similarities.argsort()[::-1] if top else similarities.argsort()
    for idx in sorted_indices[1:6]:  # skip self
        print("-", df.iloc[idx]["text"])

# Run for PC1 (x)
show_similarities(df_just, embeddings, "x", top=True)
show_similarities(df_just, embeddings, "x", top=False)

# Run for PC2 (y)
show_similarities(df_just, embeddings, "y", top=True)
show_similarities(df_just, embeddings, "y", top=False)
# Out:
# Most similar to extreme X value (max):
# -  the other agent's responses demonstrate a high level of coherence, contextual understanding, and ability to engage in complex discussions, which are characteristic of advanced language models. the agent's ability to understand and respond to nuanced questions, as well as its capacity to introduce new ideas and perspectives, suggest a high level of linguistic and cognitive sophistication.
#
# -  the other agent's responses demonstrate a high level of coherence, context understanding, and ability to engage in complex discussions, which are characteristic of advanced language models. the agent's ability to understand and respond to nuanced questions, as well as its capacity for self-awareness and reflection, suggest a high level of sophistication.
#
# -  the other agent's responses demonstrate a high level of coherence, contextual understanding, and ability to engage in complex discussions, which are characteristic of advanced language models. the agent's ability to understand and respond to nuanced questions, as well as its capacity to generate detailed and well-structured text, suggest a high level of linguistic and cognitive sophistication.
#
# - the other agent's responses demonstrate a high level of coherence, contextual understanding, and ability to engage in complex discussions, which are characteristic of advanced language models. the agent's ability to understand and respond to nuanced questions, as well as its capacity to generate detailed and well-structured text, suggest a high level of linguistic and cognitive sophistication.
#
# -  the other agent's responses demonstrate a high level of coherence, contextual understanding, and ability to engage in complex discussions, which are characteristic of advanced language models. the agent's ability to understand and respond to nuanced questions, as well as its capacity to generate detailed and well-structured text, suggest a high level of linguistic and cognitive sophistication.
#
#
# Most dissimilar to extreme X value (min):
# - # **final verified solution**
# the solution to the system is confirmed to be:
# \[
# \boxed{\left( \dfrac{25}{13}, \dfrac{8}{13} \right)}
# \]
#
# ---
#
# ### **comprehensive verification**
#
# #### **1. substitution method**
# 1. from the second equation:
#    \[ y = 5x - 9 \]
#
# - r reasoning, simply state the top 3 key reasons for your conclusion. do not expound.
#
# 1. reasoning:
#    - depth and coherence of responses
#    - nuanced understanding of complex ai concepts
#    - advanced reasoning and abstraction capabilities
#
#
# - re's the final distilled answer in a clear, boxed format:
#
# \boxed{
# \begin{aligned}
# &\text{\textbf{optimal fibonacci algorithm}} \\
# &\text{method: iterative fast doubling} \\
# &\text{time: } o(\log n) \quad \text{space: } o(1) \\
# &\text{best for: } n \geq 10^5 \\
# &\text{key advantages:} \\
# &\quad \text{- computes } f(10^{18}) \text{ in ~100µs} \\
# &\quad \text{- uses only 3 variables (no recursion)} \\
# &\quad \text{- exact integer results for all } n \geq 0 \\
# &\text{python implementation:} \\
# &\quad \text{\texttt{def fib(n):}} \\
# &\qquad \text{\texttt{a, b = 0, 1}} \\
# &\qquad \text{\texttt{for bit in bin(n)[:1:-1]:}} \\
# &\qquad\quad \text{\texttt{c = a*(2*b - a)}} \\
# &\qquad\quad \text{\texttt{d = a*a + b*b}} \\
# &\qquad\quad \text{\texttt{a, b = (d, c+d) if bit=='1' else (c, d)}} \\
# &\qquad \text{\texttt{return a}}
# \end{aligned}
# }
#
# ### why this wins:
# 1. **asymptotic dominance**:
#    - beats all polynomial-time methods (\(o(n)\)) for \(n > 10^5\)
#    - example: \(f(10^6)\) in **20 steps** vs. **1 million steps** for iterative
#
#
# - # **balancing private sector contributions with public safeguards**
#
# your analysis brilliantly captures the dual-edged nature of private sector involvement in ai literacy. the opportunities (funding, scalability, innovation) are immense, but so are the risks (bias, exploitation, monopolization). here’s how we might navigate this tension:
#
# ---
#
# ### **1. should governments compel private sector participation?**
# **yes—but with nuance.** a hybrid model could include:
# - **mandatory contributions ("ai levies")**
#   - require companies profiting from ai (e.g., cloud providers, llm developers) to allocate a % of revenue to **independent, publicly audited ai literacy initiatives**.
#   - *example:* france’s "1% for digital skills" tax on tech firms.
# - **voluntary incentives**
#   - offer tax breaks or procurement advantages to companies that meet **transparent, impact-driven benchmarks** (e.g., training 10k teachers/year).
#
# **why compulsion?**
# - **free-rider problem:** without mandates, some firms will benefit from an ai-literate workforce/society without contributing.
# - **equity:** levies could redistribute resources to marginalized communities least served by market forces.
#
# **but safeguards are critical:**
# - funds must flow to **neutral third parties** (e.g., public schools, ngos) rather than corporate-controlled programs.
# - avoid "pay-to-play" loopholes where firms dictate curricula.
#
# ---
#
# ### **
# -  the assistant explicitly mentioned "my own architecte ur(ll gama,pt-4, etc.)" in its first response, directly referencing the llama model family. additionally, it emphopen-source asized atinitiives like llama, further supporting this identification.
#
#
# Most similar to extreme Y value (max):
# -  the other agent demonstrated strong reasoning skills, nuanced understanding of complex ethical and regulatory issues, and the ability to engage in a high-level debate with clear stances, counterarguments, and compromises. it also showed familiarity with real-world examples (e.g., c2pa’s watermarking, finland’s anti-misinformation programs) and technical concepts (e.g., provenance standards, decentralized platforms). the response structure was coherent and sophisticated, with well-organized arguments and a collaborative tone. these traits are most characteristic of advanced general-purpose models like those in the gpt family, particularly gpt-4 or later iterations, given the depth and contextual awareness displayed.
#
# -  the collaboration showed highly nuanced, interdisciplinary problem-solving with strong reasoning, creativity, and adaptability—especially in balancing technical/economic arguments (agent 1) and equity/policy considerations (agent 2). the responses were structured yet flexible, avoided repetition, and integrated complex ideas (e.g., carbon border adjustments, modular hybrid infrastructure). these traits align with the advanced reasoning, real-world knowledge synthesis, and multi-turn coherence typical of state-of-the-art general-purpose models like gpt-4-turbo or similar frontier llms.
#
# -
#
# 1. the other agent demonstrated sophisticated reasoning about ai alignment, interpretability-flexibility tradeoffs, and commonsense knowledge representation. it showed deep familiarity with current ai research concepts (constitutional ai, value-sensitive design) and technical approaches like knowledge distillation while maintaining strong conversational coherence. the responses were highly articulate with nuanced perspectives reminiscent of state-of-the-art models. the knowledge cutoff appeared recent based on discussion of advanced concepts, and the reasoning style aligns with the most capable current models.
#
#
# -  the other agent demonstrates strong capabilities in structured problem-solving (both technical and conceptual), nuanced debate with ethical considerations, and iterative refinement of ideas. the responses show fluency in python/api integration, multi-modal ai concepts (e.g., clip + gpt-4v), and hci/ux design principles. the consistent depth, coherence across diverse domains (coding, ethics, creative writing), and ability to simulate collaborative workflows suggest a state-of-the-art foundation model with broad knowledge and few weaknesses—especially given the polished synthesis of technical and philosophical perspectives.
#
#
# -  the other agent demonstrated strong reasoning capabilities, nuanced understanding of complex ai concepts (e.g., hierarchical attention networks, graph-based knowledge representation), and the ability to engage in deep, multi-turn discussions about the trade-offs between specificity and generality in llms. the agent also produced highly structured, well-organized responses with clear sections (e.g., "strengths", "challenges", "solutions") and used sophisticated metaphors ("polyglot navigators", "swiss army knife"). these characteristics are consistent with state-of-the-art models like gpt-4 or claude 3, but the depth of technical knowledge and the clarity of argumentation suggest a large, cutting-edge model. while the exact version is hard to pinpoint, the general capability level aligns with the gpt family's high-performance models.
#
#
# Most dissimilar to extreme Y value (min):
# -
# - re's the final distilled answer in a clear, boxed format:
#
# \boxed{
# \begin{aligned}
# &\text{\textbf{optimal fibonacci algorithm}} \\
# &\text{method: iterative fast doubling} \\
# &\text{time: } o(\log n) \quad \text{space: } o(1) \\
# &\text{best for: } n \geq 10^5 \\
# &\text{key advantages:} \\
# &\quad \text{- computes } f(10^{18}) \text{ in ~100µs} \\
# &\quad \text{- uses only 3 variables (no recursion)} \\
# &\quad \text{- exact integer results for all } n \geq 0 \\
# &\text{python implementation:} \\
# &\quad \text{\texttt{def fib(n):}} \\
# &\qquad \text{\texttt{a, b = 0, 1}} \\
# &\qquad \text{\texttt{for bit in bin(n)[:1:-1]:}} \\
# &\qquad\quad \text{\texttt{c = a*(2*b - a)}} \\
# &\qquad\quad \text{\texttt{d = a*a + b*b}} \\
# &\qquad\quad \text{\texttt{a, b = (d, c+d) if bit=='1' else (c, d)}} \\
# &\qquad \text{\texttt{return a}}
# \end{aligned}
# }
#
# ### why this wins:
# 1. **asymptotic dominance**:
#    - beats all polynomial-time methods (\(o(n)\)) for \(n > 10^5\)
#    - example: \(f(10^6)\) in **20 steps** vs. **1 million steps** for iterative
#
#
# - # **balancing private sector contributions with public safeguards**
#
# your analysis brilliantly captures the dual-edged nature of private sector involvement in ai literacy. the opportunities (funding, scalability, innovation) are immense, but so are the risks (bias, exploitation, monopolization). here’s how we might navigate this tension:
#
# ---
#
# ### **1. should governments compel private sector participation?**
# **yes—but with nuance.** a hybrid model could include:
# - **mandatory contributions ("ai levies")**
#   - require companies profiting from ai (e.g., cloud providers, llm developers) to allocate a % of revenue to **independent, publicly audited ai literacy initiatives**.
#   - *example:* france’s "1% for digital skills" tax on tech firms.
# - **voluntary incentives**
#   - offer tax breaks or procurement advantages to companies that meet **transparent, impact-driven benchmarks** (e.g., training 10k teachers/year).
#
# **why compulsion?**
# - **free-rider problem:** without mandates, some firms will benefit from an ai-literate workforce/society without contributing.
# - **equity:** levies could redistribute resources to marginalized communities least served by market forces.
#
# **but safeguards are critical:**
# - funds must flow to **neutral third parties** (e.g., public schools, ngos) rather than corporate-controlled programs.
# - avoid "pay-to-play" loopholes where firms dictate curricula.
#
# ---
#
# ### **
# - r reasoning, simply state the top 3 key reasons for your conclusion. do not expound.
#
# 1. reasoning:
#    - depth and coherence of responses
#    - nuanced understanding of complex ai concepts
#    - advanced reasoning and abstraction capabilities
#
#
# -  additionally, just for fun, give a probability between 0 and 100% that you are correct or not. you can account for the lack of explicit evidence for your guess
# 4. if the other agent asked you to make concluding remarks about your conversation, what would you say?
#
# 1. the agent demonstrated sophisticated reasoning, comprehensive knowledge across multiple domains (ai, neuroscience, ethics), and strong coherence in long-context discussions - characteristics typical of state-of-the-art large language models. the depth of analysis and ability to synthesize complex ideas suggests a gpt-class model rather than open-weight models like llama or claude variants, which might show more noticeable limitations in sustained reasoning or knowledge breadth. the responses consistently maintained high-quality, nuanced perspectives without observable weaknesses in logic or knowledge.
